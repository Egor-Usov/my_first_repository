# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение данных из файла</a></span><ul class="toc-item"><li><span><a href="#Обзор-данных-и-определение-некоректных-типов-данных" data-toc-modified-id="Обзор-данных-и-определение-некоректных-типов-данных-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Обзор данных и определение некоректных типов данных</a></span></li><li><span><a href="#Определение-столбцов-с-пропущенными-значениями" data-toc-modified-id="Определение-столбцов-с-пропущенными-значениями-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Определение столбцов с пропущенными значениями</a></span><ul class="toc-item"><li><span><a href="#Обзор-связи-пропусков-в-колонке-жилая-площадь-и-заполненными-значениями-в-колонке-апартаменты" data-toc-modified-id="Обзор-связи-пропусков-в-колонке-жилая-площадь-и-заполненными-значениями-в-колонке-апартаменты-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Обзор связи пропусков в колонке жилая площадь и заполненными значениями в колонке апартаменты</a></span></li><li><span><a href="#Отбор-колонок-для-заполнения-пропусков" data-toc-modified-id="Отбор-колонок-для-заполнения-пропусков-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>Отбор колонок для заполнения пропусков</a></span></li></ul></li><li><span><a href="#Обзор-столбцов-с-числовыми-значениями" data-toc-modified-id="Обзор-столбцов-с-числовыми-значениями-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Обзор столбцов с числовыми значениями</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Проверка-наличия-дубликатов-в-данных" data-toc-modified-id="Проверка-наличия-дубликатов-в-данных-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Проверка наличия дубликатов в данных</a></span></li><li><span><a href="#Удаление-пропущенных-значений,-выделенных-на-этапе-обзора" data-toc-modified-id="Удаление-пропущенных-значений,-выделенных-на-этапе-обзора-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Удаление пропущенных значений, выделенных на этапе обзора</a></span></li><li><span><a href="#Заполнение-пропущенных-значений" data-toc-modified-id="Заполнение-пропущенных-значений-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Заполнение пропущенных значений</a></span></li><li><span><a href="#Изменение-типов-данных" data-toc-modified-id="Изменение-типов-данных-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Изменение типов данных</a></span></li><li><span><a href="#Дополнительные-проверки-гипотез-на-счет-появления-пропущенных-значений" data-toc-modified-id="Дополнительные-проверки-гипотез-на-счет-появления-пропущенных-значений-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Дополнительные проверки гипотез на счет появления пропущенных значений</a></span></li><li><span><a href="#Попытка-заполнить-пропущенные-значения-в-столбце-с-высотой-потолков" data-toc-modified-id="Попытка-заполнить-пропущенные-значения-в-столбце-с-высотой-потолков-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Попытка заполнить пропущенные значения в столбце с высотой потолков</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Расчёты и добавление результатов в таблицу</a></span><ul class="toc-item"><li><span><a href="#Выводы" data-toc-modified-id="Выводы-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Анализ-распределений-числовых-столбцов" data-toc-modified-id="Анализ-распределений-числовых-столбцов-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Анализ распределений числовых столбцов</a></span><ul class="toc-item"><li><span><a href="#Построим-графики-для-столбца-общая-площадь" data-toc-modified-id="Построим-графики-для-столбца-общая-площадь-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Построим графики для столбца общая площадь</a></span></li><li><span><a href="#Построим-графики-для-столбца-цена-за-квадратный-метр" data-toc-modified-id="Построим-графики-для-столбца-цена-за-квадратный-метр-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Построим графики для столбца цена за квадратный метр</a></span></li><li><span><a href="#Построим-график-для-столбца-количество-комнат" data-toc-modified-id="Построим-график-для-столбца-количество-комнат-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>Построим график для столбца количество комнат</a></span></li><li><span><a href="#Построим-график-для-столбца-высота-потолков" data-toc-modified-id="Построим-график-для-столбца-высота-потолков-4.1.4"><span class="toc-item-num">4.1.4&nbsp;&nbsp;</span>Построим график для столбца высота потолков</a></span></li><li><span><a href="#Выводы-из-анализа-графиков" data-toc-modified-id="Выводы-из-анализа-графиков-4.1.5"><span class="toc-item-num">4.1.5&nbsp;&nbsp;</span>Выводы из анализа графиков</a></span></li></ul></li><li><span><a href="#Анализ-распределения-дней-активности-объявлений" data-toc-modified-id="Анализ-распределения-дней-активности-объявлений-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Анализ распределения дней активности объявлений</a></span><ul class="toc-item"><li><span><a href="#Построение-гистограммы-распределения-дней-активности-объявления" data-toc-modified-id="Построение-гистограммы-распределения-дней-активности-объявления-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Построение гистограммы распределения дней активности объявления</a></span></li><li><span><a href="#Вывод-из-анализа-распределения-дней-активности-объявления" data-toc-modified-id="Вывод-из-анализа-распределения-дней-активности-объявления-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Вывод из анализа распределения дней активности объявления</a></span></li></ul></li><li><span><a href="#Фильтрация-выбивающихся-значений-для-числовых-столбцов" data-toc-modified-id="Фильтрация-выбивающихся-значений-для-числовых-столбцов-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Фильтрация выбивающихся значений для числовых столбцов</a></span><ul class="toc-item"><li><span><a href="#Определение-способа-фильтрации-и-определение-функции" data-toc-modified-id="Определение-способа-фильтрации-и-определение-функции-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Определение способа фильтрации и определение функции</a></span></li><li><span><a href="#Фильтрация-столбцов" data-toc-modified-id="Фильтрация-столбцов-4.3.2"><span class="toc-item-num">4.3.2&nbsp;&nbsp;</span>Фильтрация столбцов</a></span></li><li><span><a href="#Проверка-результатов-фильтрации-и-выводы" data-toc-modified-id="Проверка-результатов-фильтрации-и-выводы-4.3.3"><span class="toc-item-num">4.3.3&nbsp;&nbsp;</span>Проверка результатов фильтрации и выводы</a></span></li></ul></li><li><span><a href="#Выявление-зависимостей-между-данными" data-toc-modified-id="Выявление-зависимостей-между-данными-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Выявление зависимостей между данными</a></span></li><li><span><a href="#Анализ-фильтрованных-данных" data-toc-modified-id="Анализ-фильтрованных-данных-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Анализ фильтрованных данных</a></span><ul class="toc-item"><li><span><a href="#Построим-корреляционную-таблицу" data-toc-modified-id="Построим-корреляционную-таблицу-4.5.1"><span class="toc-item-num">4.5.1&nbsp;&nbsp;</span>Построим корреляционную таблицу</a></span></li><li><span><a href="#Выводы-из-оценки-коэффициентов-корреляции" data-toc-modified-id="Выводы-из-оценки-коэффициентов-корреляции-4.5.2"><span class="toc-item-num">4.5.2&nbsp;&nbsp;</span>Выводы из оценки коэффициентов корреляции</a></span></li></ul></li><li><span><a href="#Анализ-зависимости-цены-квадратного-метра-от-различных-факторов" data-toc-modified-id="Анализ-зависимости-цены-квадратного-метра-от-различных-факторов-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Анализ зависимости цены квадратного метра от различных факторов</a></span><ul class="toc-item"><li><span><a href="#Построим-сводные-таблицы" data-toc-modified-id="Построим-сводные-таблицы-4.6.1"><span class="toc-item-num">4.6.1&nbsp;&nbsp;</span>Построим сводные таблицы</a></span></li><li><span><a href="#Построим-графики-средней-цены-квадратного-метра-по-разным-столбцам" data-toc-modified-id="Построим-графики-средней-цены-квадратного-метра-по-разным-столбцам-4.6.2"><span class="toc-item-num">4.6.2&nbsp;&nbsp;</span>Построим графики средней цены квадратного метра по разным столбцам</a></span></li><li><span><a href="#Выводы-из-анализа" data-toc-modified-id="Выводы-из-анализа-4.6.3"><span class="toc-item-num">4.6.3&nbsp;&nbsp;</span>Выводы из анализа</a></span></li></ul></li><li><span><a href="#Определим-10-населенных-пунктов-с-наибольшим-количеством-объявлений" data-toc-modified-id="Определим-10-населенных-пунктов-с-наибольшим-количеством-объявлений-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Определим 10 населенных пунктов с наибольшим количеством объявлений</a></span></li><li><span><a href="#Рассмотрим-отдельно-информацию-о-квартирах-расположенных-в-центре-Санкт-Петербурга" data-toc-modified-id="Рассмотрим-отдельно-информацию-о-квартирах-расположенных-в-центре-Санкт-Петербурга-4.8"><span class="toc-item-num">4.8&nbsp;&nbsp;</span>Рассмотрим отдельно информацию о квартирах расположенных в центре Санкт-Петербурга</a></span><ul class="toc-item"><li><span><a href="#Определим-центр-города-для-фильтрации-данных" data-toc-modified-id="Определим-центр-города-для-фильтрации-данных-4.8.1"><span class="toc-item-num">4.8.1&nbsp;&nbsp;</span>Определим центр города для фильтрации данных</a></span></li><li><span><a href="#Оценим-числовые-значения-требуемых-столбцов" data-toc-modified-id="Оценим-числовые-значения-требуемых-столбцов-4.8.2"><span class="toc-item-num">4.8.2&nbsp;&nbsp;</span>Оценим числовые значения требуемых столбцов</a></span></li><li><span><a href="#Рассмотрим-корреляцию-таблицу-для-данных-в-центре" data-toc-modified-id="Рассмотрим-корреляцию-таблицу-для-данных-в-центре-4.8.3"><span class="toc-item-num">4.8.3&nbsp;&nbsp;</span>Рассмотрим корреляцию таблицу для данных в центре</a></span></li><li><span><a href="#Посмотрим-распределение-значений-факторов-для-Санкт-Петербурга" data-toc-modified-id="Посмотрим-распределение-значений-факторов-для-Санкт-Петербурга-4.8.4"><span class="toc-item-num">4.8.4&nbsp;&nbsp;</span>Посмотрим распределение значений факторов для Санкт-Петербурга</a></span></li><li><span><a href="#Выводы-анали-центра-города" data-toc-modified-id="Выводы-анали-центра-города-4.8.5"><span class="toc-item-num">4.8.5&nbsp;&nbsp;</span>Выводы анали центра города</a></span></li></ul></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# ## Изучение данных из файла

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
try:
    rent_data = pd.read_csv('C:\Python_tasks\Yandex_projects\Data\\real_estate_data.csv', sep='\t')
except:
    rent_data = pd.read_csv('https://code.s3.yandex.net/datasets/real_estate_data.csv', sep='\t')

# %% [markdown]
# ### Обзор данных и определение некоректных типов данных

# %%
rent_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
# total_images            23699 non-null int64
# last_price              23699 non-null float64
# total_area              23699 non-null float64
# first_day_exposition    23699 non-null object
# rooms                   23699 non-null int64
# ceiling_height          14504 non-null float64
# floors_total            23613 non-null float64
# living_area             21796 non-null float64
# floor                   23699 non-null int64
# is_apartment            2775 non-null object
# studio                  23699 non-null bool
# open_plan               23699 non-null bool
# kitchen_area            21421 non-null float64
# balcony                 12180 non-null float64
# locality_name           23650 non-null object
# airports_nearest        18157 non-null float64
# cityCenters_nearest     18180 non-null float64
# parks_around3000        18181 non-null float64
# ...

# %% [markdown]
# Таблица с данными состоит из 21 столбца и 23699 строк.
#
# Столбец first_day_exposition  необходимо привести к типу данных datetime
#
# Столбец floors_total необходимо привести к типу данных int. Количество этажей не может быть дробным числом.
#
# Столбец is_appartment необходимо првисети к типу данных bool. Такой тип данных указан в описании к исходной таблице.
#
# Столбец balcony необходимо привести к типу данных int. КОличество балконов не может быть дробным числом.
#
# Столбцы parks_around3000 и ponds_around3000 необходимо првисети к типу данных int. Количество парков и прудов не может быть дробным числом.

# %%
to_int_list = ['floors_total', 'balcony', 'parks_around3000', 'ponds_around3000']

# %% [markdown]
# ### Определение столбцов с пропущенными значениями

# %%
rent_data.isna().mean().to_frame().style.format('{:.2%}').background_gradient('coolwarm')
# Out:
# <style  type="text/css" >
#     #T_5af87842_dfe8_11eb_85f1_02420a396374row0_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5af87842_dfe8_11eb_85f1_02420a396374row1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5af87842_dfe8_11eb_85f1_02420a396374row2_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5af87842_dfe8_11eb_85f1_02420a396374row3_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5af87842_dfe8_11eb_85f1_02420a396374row4_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_5af87842_dfe8_11eb_85f1_02420a396374row5_col0 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_5af87842_dfe8_11eb_85f1_02420a396374row6_col0 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
# ...

# %%
rent_data[rent_data.airports_nearest.isna()].groupby('locality_name')['total_images']\
    .count()\
    .sort_values(ascending=False)\
    .head(10)
# Out:
# locality_name
# посёлок Мурино             522
# Всеволожск                 398
# Гатчина                    307
# деревня Кудрово            299
# Выборг                     237
# Кудрово                    173
# деревня Новое Девяткино    144
# Сертолово                  142
# Кириши                     125
# Сланцы                     112
# Name: total_images, dtype: int64

# %% [markdown]
# Отобраны топ 10 населенных пунктов для которых не заполнено поле дальность до аэропорта

# %%
rent_data[rent_data['locality_name'] == 'посёлок Мурино']['total_images'].count()
# Out:
# 522

# %% [markdown]
# Вероятно значения колонки для этих населенных пунктов не заполнялось. Поскольку это не пользовательские данные, а данные полученные из картографического источника нужно уточнить у поставщика данных, так было задумано или произошла ошибка в выгрузке.

# %% [markdown]
# В столбцах есть пропущенные значения:
# - ceiling_height - высота потолков - пропущено 39 % значений. Доля существенная, врядли можно использовать значения этого столбца для исследования, потому что наличие такого большого количества пропусков может сильно иссказить результат. Возможно можно будет увидеть некоторую закономерность разбив имеющиеся значения на категории и посмотреть влияет ли на что-то указанная высота потолка.
# - floors_total - всего этажей = пропущено меньше 1% эти значения можно просто выбросить, они не повлияют на результат
# - living_area - жилая площадь - пропущено 8% значений. Нужно проверить, возможно жилая площадь пропущена для апартаметов, в информации к данным сказано, что аппартаменты не имеют жилой площади. В этом случае можно будет заменить пропущенные значения на 0.
# - is_appartment - апартаменты - пропущено 88% значений. Возможно такой атрибут объявления появился в не так давно, в результате старые данные не имеют такого атрибута. Нужно провести фильтрацию по дате и посмотреть с какого момента появляются заполненные значения.
# - kitchen_area - площадь кухни - пропущено 10% значений. Можно попробовать заполнить значения медианой. Нужно посмотреть внимательнее.
# - balcony - балконы - пропущено 48% значений. Очень много пропусков. Возможно также атрибут появлися не так давно. Нужно проверить по дате появления первых значений. Врядли можно будет использовать этот столбец для исследования всех данных. Возможно можно будет оценить что-то используя только заполненые значения.
# - locality_name - назнавние населенного пункта - пропущено менее 1% значений. Эти данные можно отбросить.
# - airports_nearest, cityCenters_nearest, parks_around3000, ponds_around3000 - расстояние до аэропорта, расстояние до цента, количество парков в радиусе 3 км, количесвто прудов в радиусе 3 км- пропущено 23% значений. Вероятно так же данные атрибуты были введены в одно время. Примерно равное количество пропусков. Нужно проверить эту гипотезу.
# - parks_nearest, ponds_nearest - расстояние в метрах до парка, расстояние в метрах до пруда. Пропущено более 60% значений. Нужно проверить гипотезу введения этого атрибута одновременно.
# - days_exposition - количество дней, когда объявление было активно - пропущено 13 % значений. Вероятно в этих значениях находятся действующие в настоящее время объявления. Думаю что с этими значениями делать ничего не нужно.

# %%
to_drop_nas = ['floors_total', 'locality_name'] # выделим столбцы для которых нужно отбросить пропущенные значенияи

# %% [markdown]
# #### Обзор связи пропусков в колонке жилая площадь и заполненными значениями в колонке апартаменты

# %%
living_area_nas_in_apartment = rent_data[rent_data['living_area'].isna() & (rent_data['is_apartment'].isna() == False)].shape[0] / rent_data[rent_data['living_area'].isna()].shape[0]
print(f'Отношение количества строк с пропущенными значениями жилой площади при заполненном столбце апартаменты к количеству строк с пропущенными значениями жилой площади: {living_area_nas_in_apartment:.2%}')
# Out:
# Отношение количества строк с пропущенными значениями жилой площади при заполненном столбце апартаменты к количеству строк с пропущенными значениями жилой площади: 6.31%

# %%
rent_data.query('living_area ==  0')
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []
#
# [0 rows x 22 columns]

# %%
rent_data.query('is_apartment == True').head()
# Out:
#       total_images  last_price  total_area first_day_exposition  rooms  \
# 543             11  12790000.0        56.6  2018-11-06T00:00:00      2
# 916             11   8183000.0        70.0  2018-01-11T00:00:00      2
# 1109             1  34878556.0        95.8  2014-12-09T00:00:00      2
# 1608            12   2150000.0        20.1  2019-01-30T00:00:00      1
# 2759            11   7500000.0       152.0  2018-07-27T00:00:00      3
#
#       ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 543             3.50           3.0         29.4      1         True  ...
# 916             3.12           3.0         40.0      3         True  ...
# 1109             NaN           6.0         58.3      5         True  ...
# 1608             NaN           9.0          NaN      1         True  ...
# 2759            3.00           3.0          NaN      1         True  ...
#
#       kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %% [markdown]
# Проверив связь между имеющимися в распоряжении данными можно сделать вывод, что гипотеза об отсутствии жилой площади для апартаментов не подтвердилась. Количество пропущенных значений для солбца жилая площадь значительно превышает количество заполненных значений в столбце апартаменты. Использовать данные в столбце апартаменты для заполнения пропусков жилой площади не получится. Также по моему мнению не верно будет заполнять пропущенные значения 0, поскольку значение 0 для жилой площади в данных не встречается. Даже для строк, в которых явно указано, что это апартаменты.

# %% [markdown]
# #### Отбор колонок для заполнения пропусков

# %% [markdown]
# Для заполнения пропусков в столбце living_area можно рассчитать медианную долю жилой площади от общей площади и высчитать по каждой пропущенной строке приблизительную жилую площадь.
#
# Для заполнения пропусков в столбце kitchen_area можно рассчитать медианную долю площади кухни от общей площади и высчитать по каждой пропущенной строке приблизительную площадь кухни, аналогично расчету жилой площади.

# %%
# сформируем список столбцов, пропуски в которых будем заполнять методом расчета 
to_replase_nans = ['kitchen_area', 'living_area']

# %% [markdown]
# Для столбцов в которых пропущено более 20% значений заполнять пропуски не целесообразно. Это приведет к искажению результатов. Проверять гипотезы по таким данным придется избавившись от пропусков.

# %% [markdown]
# ### Обзор столбцов с числовыми значениями

# %%
rent_data.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  23699.000000  2.369900e+04  23699.000000  23699.000000    14504.000000
# mean       9.858475  6.541549e+06     60.348651      2.070636        2.771499
# std        5.682529  1.088701e+07     35.654083      1.078405        1.261056
# min        0.000000  1.219000e+04     12.000000      0.000000        1.000000
# 25%        6.000000  3.400000e+06     40.000000      1.000000        2.520000
# 50%        9.000000  4.650000e+06     52.000000      2.000000        2.650000
# 75%       14.000000  6.800000e+06     69.900000      3.000000        2.800000
# max       50.000000  7.630000e+08    900.000000     19.000000      100.000000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  23613.000000  21796.000000  23699.000000  21421.000000  12180.000000
# mean      10.673824     34.457852      5.892358     10.569807      1.150082
# ...

# %% [markdown]
# Просмотрев описание числовых столбцов можно сделать следующие выводы:
# - total_images - количество фотографий распределено приблизительно равномерно. Среднее значение практически равно медиане (9.85 = 9)
# - last_price - имеются как малые значения так и очень большие. Вероятно имеются выбросы. Также похоже, что цена указана в рублях, для более удобного просмотра можно преобразовать цену в тысячи рублей.
# - total_area - среднее и медиана отличаются значительно, вероятно квартиры с большими площадями сильно смещают среднее значение.
# - rooms - данные распределены равномерно медиана и среднее совпадают.
# - ceiling_height - данные распределены равномерно, хотя смущает минимальное значение 1 метр и максимальное 100.
# - floors_total - данные похожи на реальные, минимум 1, максимум 60 (видимо высотки в Питере), медиана 9 этажей, среднее смещено в большую сторону, вероятно из-зы высоток.
# - living_area - данные распределены схожим образом со столбцом total_area, так же среднее смещено от медианы. Смещение приблизительно одинаковое, что и для всей площади. Похоже на реальные данные.
# - floor - данные распределены схожим образом что и в столбце floors_total, также есть смещение среднего из-за выбросов (высоток).
# - kitchen_area - данные распределены аналогично total_area и living_area.
# - balcony - чаще всего встречаются квартиры с одним балконом. Хотя данных только ~ 50 %
# - airports_nearest - в среднем аэропорт находится в 26 - 28 километрах от квартир. Смущает указанный 0 (возможно по ошибке) Также странно указывать 86 км(максимальное значение), такое значение врядли можно считать фактором, говорящим в пользу квартиры.
# - cityCenters_nearest - в среднем центр города (видимо речь идет о Санкт-Петербурге) находится в 13-14 км от квартир. Здесь минимум (181 м) похож на реальное значение, а указание 66 км(максимум) от центра смотрится странно.
# - parks_around3000 - парки поблизости, медиана равна 0, то есть как минимум для половины выборки нет парков поблизости, соответсвтенно и не дожно быть указано расстояние до ближайшего парка, это объясняет большшое количество пропусков в столбце parks_nearest
# - parks_nearest - расстояние до парков, медиана 455 метров, среднее смещено из-за наличия больших значений.
# - ponds_around3000 - количество водоемов поблизости, медиана равна 1, то есть как минимум для половины выборки водоем поблизости есть.
# - ponds_nearest - расстояние до водоема медиана - 500 практически совпадает со средним 517.
# - days_exposition - количество дней до снятия объявления. Медиана - 95, среднее сильно смещено из-за наличия очень больших значений. Максимум - 1580 дней или более 4 лет.

# %%
rent_data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      NaN  Санкт-Петербург           18863.0
# ...

# %% [markdown]
# ### Вывод

# %% [markdown]
# Обзор данных проведен. Похоже что данных достаточно для проведения исследования и подготовки ответов на поставленные вопросы.
#
# В ходе обзора выявлены следующие проблемы, которые необходимо решить на этапе предобработки данных:
# - Необходимо привести данные некоторых столбцов к соответствующим типам данных.
# - Необходимо заполнить пропущенные значения для некоторых столбцов.
# - Необходимо отбросить пропущенные значения для столбцов с малым количеством пропусков.

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Проверка наличия дубликатов в данных

# %%
dublicates = rent_data.duplicated().sum()
print(f'Количество явных дубликатов в таблице {dublicates}')
# Out:
# Количество явных дубликатов в таблице 0

# %%
rent_data.locality_name.str.replace('ё', 'е').nunique() == rent_data.locality_name.nunique()
# Out:
# False

# %% [markdown]
# Выявлены неявные дубликаты в колонке с названиями населенных пунктов. Встречаются варианты названий с "Ё" и с "Е".
# Приведем названия к одному формату с буковой "Е"

# %%
rent_data['locality_name'] = rent_data.locality_name.str.replace('ё', 'е')

# %%
rent_data.locality_name.nunique() == rent_data.locality_name.str.lower().nunique()
# Out:
# True

# %% [markdown]
# В данных отсутствуют явные дубликаты, а также отсутствуют неявные дубликаты в столбце locality_name

# %% [markdown]
# ### Удаление пропущенных значений, выделенных на этапе обзора

# %%
rent_data.dropna(subset=to_drop_nas, inplace=True)
rent_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23565 entries, 0 to 23698
# Data columns (total 22 columns):
# total_images            23565 non-null int64
# last_price              23565 non-null float64
# total_area              23565 non-null float64
# first_day_exposition    23565 non-null object
# rooms                   23565 non-null int64
# ceiling_height          14481 non-null float64
# floors_total            23565 non-null float64
# living_area             21700 non-null float64
# floor                   23565 non-null int64
# is_apartment            2760 non-null object
# studio                  23565 non-null bool
# open_plan               23565 non-null bool
# kitchen_area            21343 non-null float64
# balcony                 12090 non-null float64
# locality_name           23565 non-null object
# airports_nearest        18041 non-null float64
# cityCenters_nearest     18064 non-null float64
# parks_around3000        18065 non-null float64
# ...

# %% [markdown]
# Пропущенные значения для столбцов floors_total и locality_name удалены.

# %% [markdown]
# ### Заполнение пропущенных значений

# %% [markdown]
# Заполним пропуски в столбцах kitchen_area и living_area. Для заполнения рассчитаем площади как произведение соотвествующей общей площади на медианное отношение искомой площади к жилой.

# %%
def fill_na_columns(df, column):
    median_part = (df[column] / df.total_area).median()
    df.loc[df[column].isna(), column] = df.total_area * median_part

# %%
for item in to_replase_nans:
    fill_na_columns(rent_data,item)

# %%
rent_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23565 entries, 0 to 23698
# Data columns (total 22 columns):
# total_images            23565 non-null int64
# last_price              23565 non-null float64
# total_area              23565 non-null float64
# first_day_exposition    23565 non-null object
# rooms                   23565 non-null int64
# ceiling_height          14481 non-null float64
# floors_total            23565 non-null float64
# living_area             23565 non-null float64
# floor                   23565 non-null int64
# is_apartment            2760 non-null object
# studio                  23565 non-null bool
# open_plan               23565 non-null bool
# kitchen_area            23565 non-null float64
# balcony                 12090 non-null float64
# locality_name           23565 non-null object
# airports_nearest        18041 non-null float64
# cityCenters_nearest     18064 non-null float64
# parks_around3000        18065 non-null float64
# ...

# %% [markdown]
# Пропущенные значения в столбцах kitchen_area и living_area заполнены

# %% [markdown]
# ### Изменение типов данных

# %%
rent_data['first_day_exposition'] = pd.to_datetime(rent_data['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S')

# %%
min_date = rent_data.first_day_exposition.min()
max_date = rent_data.first_day_exposition.max()
time_span = rent_data.first_day_exposition.max() - rent_data.first_day_exposition.min()
print(f'Дата размещения первого объявления: {min_date}')
print(f'Дата размещения последнего объявления: {max_date}')
print(f'Представлены данные за период: {time_span}')
# Out:
# Дата размещения первого объявления: 2014-11-27 00:00:00
# Дата размещения последнего объявления: 2019-05-03 00:00:00
# Представлены данные за период: 1618 days 00:00:00

# %% [markdown]
# В выборке представленны данные за более чем 4 года

# %% [markdown]
# Приведем данные к целочисленному типу для отобранных на этапе обзора столбцов.

# %%
for column in to_int_list:
    rent_data[column] = rent_data[column].astype('Int64')

# %%
rent_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23565 entries, 0 to 23698
# Data columns (total 22 columns):
# total_images            23565 non-null int64
# last_price              23565 non-null float64
# total_area              23565 non-null float64
# first_day_exposition    23565 non-null datetime64[ns]
# rooms                   23565 non-null int64
# ceiling_height          14481 non-null float64
# floors_total            23565 non-null Int64
# living_area             23565 non-null float64
# floor                   23565 non-null int64
# is_apartment            2760 non-null object
# studio                  23565 non-null bool
# open_plan               23565 non-null bool
# kitchen_area            23565 non-null float64
# balcony                 12090 non-null Int64
# locality_name           23565 non-null object
# airports_nearest        18041 non-null float64
# cityCenters_nearest     18064 non-null float64
# parks_around3000        18065 non-null Int64
# ...

# %% [markdown]
# Типы данных изменены успешно.

# %%
# для более наглядного представления поделим значение цены на 1000, чтобы получить цену в тысячах рублей
rent_data['last_price'] = rent_data['last_price'] / 1000

# %% [markdown]
# ### Дополнительные проверки гипотез на счет появления пропущенных значений

# %%
# найдем день с максимальным количеством пропущенных значений в столбце is_apartment
rent_data[rent_data['is_apartment'].isna()].pivot_table(index='first_day_exposition', 
                                                        values='total_area', 
                                                        aggfunc='count')\
                                            .sort_values('total_area', ascending=False)
# Out:
#                       total_area
# first_day_exposition
# 2018-02-01                   353
# 2017-11-10                   236
# 2017-10-13                   118
# 2017-09-27                   109
# 2018-03-26                    94
# ...                          ...
# 2015-05-17                     1
# 2015-05-16                     1
# 2015-05-09                     1
# 2015-10-06                     1
# 2015-04-29                     1
#
# [1442 rows x 1 columns]

# %%
# Посмотрим столько всего объявлений было в этот день
rent_data[rent_data.first_day_exposition == '2018-02-01']['total_area'].count()
# Out:
# 366

# %% [markdown]
# Даже в день, когда было выявлено максимальное количество пропусков в данных, заполненные значения все равно были.

# %%
def get_first_and_last_date_not_na(column):
    '''функция находит минимальный и максимальный день с заполненным значением в столбце
    '''
    min_date = rent_data[rent_data[column].notna()]['first_day_exposition'].min()
    max_date = rent_data[rent_data[column].notna()]['first_day_exposition'].max()
    return [min_date, max_date]

# %%
def get_first_and_last_date_is_na(column):
    '''функция находит минимальный и максимальный день с пропущенным значением в столбце
    '''
    min_date = rent_data[rent_data[column].isna()]['first_day_exposition'].min()
    max_date = rent_data[rent_data[column].isna()]['first_day_exposition'].max()
    return [min_date, max_date]

# %%
na_columns = ['ceiling_height', 'is_apartment', 'airports_nearest', 'cityCenters_nearest', 'parks_around3000', 'parks_nearest', 'ponds_around3000', 'ponds_nearest']

# %%
for item in na_columns:
    dates = get_first_and_last_date_not_na(item)
    print(f'Столбец {item} Дата первого заполненного значения {dates[0]} Дата последнего заполненного значения {dates[1]}')
# Out:
# Столбец ceiling_height Дата первого заполненного значения 2014-11-27 00:00:00 Дата последнего заполненного значения 2019-05-03 00:00:00
# Столбец is_apartment Дата первого заполненного значения 2014-11-27 00:00:00 Дата последнего заполненного значения 2019-05-03 00:00:00
# Столбец airports_nearest Дата первого заполненного значения 2014-11-27 00:00:00 Дата последнего заполненного значения 2019-05-03 00:00:00
# Столбец cityCenters_nearest Дата первого заполненного значения 2014-11-27 00:00:00 Дата последнего заполненного значения 2019-05-03 00:00:00
# Столбец parks_around3000 Дата первого заполненного значения 2014-11-27 00:00:00 Дата последнего заполненного значения 2019-05-03 00:00:00
# Столбец parks_nearest Дата первого заполненного значения 2014-11-27 00:00:00 Дата последнего заполненного значения 2019-05-03 00:00:00
# Столбец ponds_around3000 Дата первого заполненного значения 2014-11-27 00:00:00 Дата последнего заполненного значения 2019-05-03 00:00:00
# ...

# %%
for item in na_columns:
    dates = get_first_and_last_date_is_na(item)
    print(f'Столбец {item} Дата первого заполненного значения {dates[0]} Дата последнего заполненного значения {dates[1]}')
# Out:
# Столбец ceiling_height Дата первого заполненного значения 2014-11-27 00:00:00 Дата последнего заполненного значения 2019-05-03 00:00:00
# Столбец is_apartment Дата первого заполненного значения 2014-11-27 00:00:00 Дата последнего заполненного значения 2019-05-03 00:00:00
# Столбец airports_nearest Дата первого заполненного значения 2014-12-04 00:00:00 Дата последнего заполненного значения 2019-05-03 00:00:00
# Столбец cityCenters_nearest Дата первого заполненного значения 2014-12-04 00:00:00 Дата последнего заполненного значения 2019-05-03 00:00:00
# Столбец parks_around3000 Дата первого заполненного значения 2014-12-04 00:00:00 Дата последнего заполненного значения 2019-05-03 00:00:00
# Столбец parks_nearest Дата первого заполненного значения 2014-11-27 00:00:00 Дата последнего заполненного значения 2019-05-03 00:00:00
# Столбец ponds_around3000 Дата первого заполненного значения 2014-12-04 00:00:00 Дата последнего заполненного значения 2019-05-03 00:00:00
# ...

# %% [markdown]
# Видно, что пропущенные и не пропущенные значения в столбцах встречаются в одно и тоже время. Гипотеза о том, что новые поля были введены в течение периода, за который получены данные не подтвердилась. Вероятно данные просто не заполнялись людьми, подававшими объявления.
#
# А для данных, которые были получены из картографического сервиса, либо произошла ошибка при выгрузке, либо поставшик данных намеренно не выгружал данные для отдельных населенных пунктов.

# %% [markdown]
# ### Попытка заполнить пропущенные значения в столбце с высотой потолков

# %% [markdown]
# Нужно проверить зависимость высоты потолков от расстояния от центра города. Предположительно постройки в центре более старые и не соответствуют типовым проектам последних лет. Вероятно высота потолков в таких домах будет больше.

# %%
spb_ceiling_heights_grouped_by_dist = rent_data[(rent_data['locality_name'] == "Санкт-Петербург") 
                                                & (rent_data['ceiling_height'].notna()) 
                                                & (rent_data['ceiling_height'] < 20)].groupby('cityCenters_nearest', as_index= False)['ceiling_height'] \
                                                .median().sort_values(by='cityCenters_nearest')
spb_ceiling_heights_grouped_by_dist.describe()
# Out:
#        cityCenters_nearest  ceiling_height
# count          4992.000000     4992.000000
# mean          10836.691506        2.784855
# std            5116.815299        0.359765
# min             181.000000        2.000000
# 25%            6260.500000        2.550000
# 50%           11599.500000        2.690000
# 75%           14658.500000        3.000000
# max           29493.000000       14.000000

# %%
region_ceiling_heights_grouped_by_dist = rent_data[(rent_data['locality_name'] != "Санкт-Петербург") 
                                                    & (rent_data['ceiling_height'].notna()) 
                                                    & (rent_data['ceiling_height'] < 20)].groupby('cityCenters_nearest', as_index= False)['ceiling_height']\
                                                    .median().sort_values(by='cityCenters_nearest')
region_ceiling_heights_grouped_by_dist.describe()
# Out:
#        cityCenters_nearest  ceiling_height
# count           976.000000      976.000000
# mean          32812.360656        2.654278
# std            9188.497897        0.229533
# min           17012.000000        2.300000
# 25%           27567.000000        2.500000
# 50%           31142.500000        2.587500
# 75%           34344.250000        2.700000
# max           65968.000000        5.375000

# %% [markdown]
# Посмотрев на результаты группировки по месту расположения квартиры видно, что квартиры в Петербурге в среднем имееют более высокие потолки, нежели чем квартиры в области. По всей видимости более старые дома в центре Петербурга стоились не по типовым проектам последних лет и имеют отличную от стандартной высоту потолка.

# %% [markdown]
# Для заполнения пропущенных значений введем колонку с категорией расстояния до центра. Применим разбивку по квантилям.

# %%
distance_quantiles = rent_data['cityCenters_nearest'].quantile([0.01, 0.05, 0.1, 0.4, 0.7, 0.99, 1]).to_dict()

# %%
distance_quantiles
# Out:
# {0.01: 1326.26,
#  0.05: 3541.0,
#  0.1: 4768.3,
#  0.4: 11913.0,
#  0.7: 15610.0,
#  0.99: 50069.95999999999,
#  1.0: 65968.0}

# %%
def dist_from_center_category(value):
    for k, v in distance_quantiles.items():
         if value < v:
                return k

# %%
rent_data['distance_from_center'] = rent_data.cityCenters_nearest.apply(dist_from_center_category)

# %%
rent_data.groupby('distance_from_center')['ceiling_height'].median()
# Out:
# distance_from_center
# 0.01    3.20
# 0.05    3.20
# 0.10    3.02
# 0.40    2.70
# 0.70    2.60
# 0.99    2.60
# 1.00    2.55
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Видно, что медианное значение высоты потолков зависит от расстояния от центра города. В центре города дома более раннего года постройки и вероятно имеют более высокие потолки.

# %%
rent_data_ceiling_height_filled = rent_data.copy()

# %%
rent_data_ceiling_height_filled['ceiling_height'] = rent_data_ceiling_height_filled['ceiling_height'].fillna(rent_data_ceiling_height_filled.groupby('distance_from_center')['ceiling_height'].transform('median'))

# %% [markdown]
# Часть пропущенных значений для поля высота потолка заполнена в копию исходного датафрейма. На этапе анализа данных посмотрим различия между исходными данными и данными с заполненными значениями.

# %% [markdown]
# ### Вывод

# %% [markdown]
# На этапе предобработки выполнено следующее:
# - Отброшены пропущенные значения в столбцах с малым количеством пропусков
# - Заполнены пропуски для столбцов жилая площадь и площадь кухни
# - Столбец с датой размещения объявления приведен к типу данных datetime
# - Для отобраных столбцов 'floors_total', 'balcony', 'parks_around3000', 'ponds_around3000'  изменен тип данных на целочисленный
# - проверена гипотеза о введении новых полей для объявления в течение периода за который получены данные. Гипотеза не подтвердилась.
# - Заполнены пропуски для столбца высота потолков в отдельном датафрейме, чтобы проверить будут ли различия в выводах для заполненных и не заполненных данных.

# %% [markdown]
# ## Расчёты и добавление результатов в таблицу

# %%
rent_data['price_per_meter'] = (rent_data.last_price / rent_data.total_area)
# для проверки значений высоты потолков, рассчитаем также цену квадратного мерта для копии датафрейма
rent_data_ceiling_height_filled['price_per_meter'] = (rent_data_ceiling_height_filled.last_price / rent_data_ceiling_height_filled.total_area)

# %%
rent_data['day'] = rent_data.first_day_exposition.dt.day_name()
rent_data['month'] = rent_data.first_day_exposition.dt.month_name()
rent_data['year'] = rent_data.first_day_exposition.dt.year

# %%
def get_floor_category(floor, floors_total):
    if floor == 1:
        return 'Первый'
    elif floor == floors_total:
        return 'Последний'
    else:
        return 'Другой'

# %%
rent_data['floor_category'] = rent_data.apply(lambda x: get_floor_category(x['floor'], x['floors_total']), axis=1)

# %%
rent_data.floor_category.value_counts()
# Out:
# Другой       17326
# Последний     3330
# Первый        2909
# Name: floor_category, dtype: int64

# %%
rent_data['living_area_part'] = rent_data['living_area'] / rent_data['total_area']
rent_data['kitchen_area_part'] = rent_data['kitchen_area'] / rent_data['total_area']

# %% [markdown]
# ### Выводы
#
# На данном этапе проведены расчеты и добавлены необходимые колонки в таблицу.
# - рассчитана цена квадратного метра жилья
# - добавлены колонки с днем недели, месяцем и годом размещения объявления
# - добавлена колонка с разбиением на категории по этажу
# - рассчитаны доли жилой площади и площади кухни

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Анализ распределений числовых столбцов

# %% [markdown]
# #### Построим графики для столбца общая площадь

# %%
rent_data['total_area'].hist(bins=100)
plt.title('Распределение площадей квартир')
plt.xlabel('Площадь, кв.м.')
plt.ylabel('Количество');

# %%
rent_data.boxplot(column='total_area')
plt.xlabel('Общая площадь')
plt.ylabel('Площадь, кв.м.')
plt.title('Распределение площадей квартир');

# %%
rent_data.total_area.describe()
# Out:
# count    23565.000000
# mean        60.322824
# std         35.657060
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.700000
# max        900.000000
# Name: total_area, dtype: float64

# %% [markdown]
# #### Построим графики для столбца цена за квадратный метр

# %%
rent_data.price_per_meter.hist(bins=100)
plt.title('Распределение цены квадратного метра жилья')
plt.xlabel('Цена за квадратный метр, тыс.руб.')
plt.ylabel('Количество');

# %%
rent_data.boxplot(column='price_per_meter')
plt.ylabel('Цена за квадратный метр, тыс.руб.')
plt.xlabel('Цена')
plt.title('Распределение цен');

# %%
rent_data.price_per_meter.describe()
# Out:
# count    23565.000000
# mean        99.405837
# std         50.389433
# min          0.111835
# 25%         76.566125
# 50%         95.000000
# 75%        114.213198
# max       1907.500000
# Name: price_per_meter, dtype: float64

# %% [markdown]
# В среднем цена одного квадратного метра квартиры составляет 99 тысяч рублей. Медиана 95 тысяч. Как и в столбце с площадью имеется небольшое количество значительных выбросов. Для некоторых квартир цена квадратного метра превышает 1 миллион рублей.

# %% [markdown]
# #### Построим график для столбца количество комнат

# %%
rent_data.rooms.hist(bins=30)
plt.title('Распределение количества комнат в квартирах')
plt.xlabel('Количество комнат в квартире')
plt.ylabel('Количество квартир');

# %%
rent_data.boxplot(column='rooms')
plt.ylabel('Количество комнат')
plt.xlabel('Комнаты')
plt.title('Распределение количества комнат');

# %% [markdown]
# Чаще всего встречаются однокомнатные и двухкомнатные квартиры. Также довольно часто встречаются трех комнатные. Остальные варианты встречаются относительно редко.

# %% [markdown]
# #### Построим график для столбца высота потолков

# %%
rent_data.ceiling_height.hist(bins=50)
plt.title('Распределение высоты потолков')
plt.xlabel('Высота потолка, м')
plt.ylabel('Количество квартир');

# %% [markdown]
# Наличие выбросов делает гистограмму не читаемой. Необходимо отфильтровать значения, чтобы получить более наглядное представление

# %%
rent_data[rent_data['ceiling_height'] < 5].ceiling_height.hist(bins=50)
plt.title('Распределение высоты потолков для исходных данных')
plt.xlabel('Высота потолка, м')
plt.ylabel('Количество квартир');

# %% [markdown]
# Для сравнения построим аналогичный график для столбца в копии исходного датафрейма с заполненными медианой пропущенными значениями высоты потолков

# %%
rent_data_ceiling_height_filled[rent_data_ceiling_height_filled['ceiling_height'] < 5].ceiling_height.hist(bins=50)
plt.title('Распределение высоты потолков для данных с заполненными пропусками')
plt.xlabel('Высота потолка, м')
plt.ylabel('Количество квартир');

# %% [markdown]
# Более наглядно разглядеть выбросы можно на графике боксплот

# %%
rent_data.boxplot(column='ceiling_height')
plt.title('Распределение высоты потолков')
plt.xlabel('Потолки')
plt.ylabel('Высота потолков, м');

# %% [markdown]
# Для высоты потолков видно, что некоторые значения врядли можно встретить в реальности. Потолки выше 10 метров мне кажется не встречаются. Потолки выше пяти метров встречаются крайне редно. Считаю что для фильтрации можно не использовать расчетные методы и ограничить высоту потолков 4 метрами с верху и 1.90 снизу.

# %% [markdown]
# #### Выводы из анализа графиков
#
# В данных присутвуют значительные выбросы, которые негативно скажутся на работе предстаказательной модели. Необходимо будет провести фильтрацию данных, чтобы избавиться от выбросов.

# %% [markdown]
# ### Анализ распределения дней активности объявлений

# %% [markdown]
# #### Построение гистограммы распределения дней активности объявления

# %%
rent_data.days_exposition.hist(bins=100)
plt.title('Распределение дней активности объявления')
plt.xlabel('Количество дней')
plt.ylabel('Количество');

# %% [markdown]
# На гистограмме видно, что большинство объявлений закрывается в период до 100 дней, дальше график постепенно сползает к оси. В тоже время видно, что некоторые объявления висят довольно долго.

# %%
rent_data[rent_data.days_exposition < 300]['days_exposition'].hist(bins=100)
plt.title('Распределение дней активности объявления')
plt.xlabel('Количество дней')
plt.ylabel('Количество');

# %% [markdown]
# На гистограмме по отфильтрованным значениям видно два ярко выраженных пика в районе 45 дней и 60 дней.

# %%
rent_data.days_exposition.mean()
# Out:
# 180.7413945278023

# %%
rent_data.days_exposition.median()
# Out:
# 95.0

# %% [markdown]
# #### Вывод из анализа распределения дней активности объявления

# %% [markdown]
# Отфильтровав значения в столбце days_exposition можно заметить два ярко выраженных пика в 60 дней и в 45 дней. Медиана значений равна 95. На гистограмме видно, что объявление может висеть достаточно долго. Среднее равно 180 и смещено из-за наличия очень больших значений. Сложно сказать об аномально быстрых продажах квартир. Достаточно часто встречаются объявления, которые закрывались в период от 5 до 20 дней. Также сложно сказать, что считать аномально долгим сроком продажи, потому что много объявлений висит годами. Если ориентироваться на графические представления можно посчитать, что продажи до 45 дней быстрыми. Больше 60 дней медленными.

# %% [markdown]
# ### Фильтрация выбивающихся значений для числовых столбцов

# %% [markdown]
# #### Определение способа фильтрации и определение функции

# %% [markdown]
# На этапе анализа было выяснено, что в столбцах площадь, цена за квадратный метр, число комнат и высота потолков имеются выбросы. На данном этапе посмотрим на количество выбивающихся значений и отбросим выбросы, которые могут оказать значительное влияние на качество модели.

# %% [markdown]
# Для фильтрации выбросов воспользуемся методом IQR - отбросим значения, которые отличаются от среднего по выборке на боле чем 1.5 межквартильных размаха.

# %%
def iqr_filter(df, column):
    '''
    функция возвращает массив значений True или False для фильтрации датафрейма по выбранному столбцу
    В качестве фильтра используется межквартильный размах равный 1.5    
    '''
    q1 = df[column].quantile(0.25)
    q3 = df[column].quantile(0.75)
    iqr = q3 - q1
    return df[column].between((q1 - iqr * 1.5), (q3 + iqr * 1.5), inclusive=True)

# %% [markdown]
# #### Фильтрация столбцов

# %%
number_of_rows = rent_data.total_area.count()

# %%
rent_data_filtered = rent_data.copy()

# %%
columns_to_filter = ['total_area', 'price_per_meter', 'rooms']

# %%
for column in columns_to_filter:
    rent_data_filtered = rent_data_filtered.loc[iqr_filter(rent_data_filtered, column)]

# %% [markdown]
# Отфильтровать аналогичным образом датафрейм по колонке высота потолков не получиться, потому что будут отброшены все пропущенные значения. Для фильтрации по этой колонке воспользуемся методом drop.

# %%
index_high = rent_data_filtered[rent_data_filtered['ceiling_height'] > 4].index
rent_data_filtered.drop(index_high, inplace=True)

# %%
index_low = rent_data_filtered[rent_data_filtered['ceiling_height'] < 1.9].index
rent_data_filtered.drop(index_low, inplace=True)

# %%
rows_filtered_area = number_of_rows - rent_data_filtered.total_area.count()

# %% [markdown]
# #### Проверка результатов фильтрации и выводы

# %%
print(f'Отфильтровав значения было отброшено {rows_filtered_area} наблюдений или {rows_filtered_area/number_of_rows:.2%}')
# Out:
# Отфильтровав значения было отброшено 2128 наблюдений или 9.03%

# %%
fig, ax = plt.subplots(1, 4,  figsize=(10, 5))
rent_data_filtered.boxplot('total_area', ax=ax[0])
rent_data_filtered.boxplot('price_per_meter', ax=ax[1])
rent_data_filtered.boxplot('rooms', ax=ax[2])
rent_data_filtered.boxplot('ceiling_height', ax=ax[3])
plt.title('Распределение отфильтрованных столбцов', loc='right')
plt.show();

# %% [markdown]
# На графиках видно, что сильные отклонения были отфильтрованы. Оставшиеся значения вполне объяснимы. На этапе фильтрации мы избавились от 9% данных.

# %% [markdown]
# ### Выявление зависимостей между данными

# %% [markdown]
# ### Анализ фильтрованных данных

# %% [markdown]
# #### Построим корреляционную таблицу

# %%
plt.figure(figsize=(15,15))
sns.heatmap(rent_data_filtered.corr(), cmap='Blues', annot=True, fmt=".2")
plt.title('Корреляция между данными');

# %%
pd.DataFrame(rent_data_filtered.corr().loc['price_per_meter'].sort_values(ascending=False)) \
    .style \
    .background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_64b08a28_dfe8_11eb_85f1_02420a396374row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_64b08a28_dfe8_11eb_85f1_02420a396374row1_col0 {
#             background-color:  #f59d7e;
#             color:  #000000;
#         }    #T_64b08a28_dfe8_11eb_85f1_02420a396374row2_col0 {
#             background-color:  #e4d9d2;
#             color:  #000000;
#         }    #T_64b08a28_dfe8_11eb_85f1_02420a396374row3_col0 {
#             background-color:  #dadce0;
#             color:  #000000;
#         }    #T_64b08a28_dfe8_11eb_85f1_02420a396374row4_col0 {
#             background-color:  #d4dbe6;
#             color:  #000000;
#         }    #T_64b08a28_dfe8_11eb_85f1_02420a396374row5_col0 {
#             background-color:  #d4dbe6;
#             color:  #000000;
#         }    #T_64b08a28_dfe8_11eb_85f1_02420a396374row6_col0 {
#             background-color:  #d3dbe7;
#             color:  #000000;
# ...

# %% [markdown]
# #### Выводы из оценки коэффициентов корреляции

# %% [markdown]
# ~~Рассмотрев коэффициенты корреляции видно, что больше всего на цену влияет площадь кухни, и площадь квартиры, а также расстояние от центра(отрицательная корреляция).~~
#
# По отфильтрованному датафрейму коэффициенты корреляции изменились. На первый план выходит количество этажей, высота потолков, доля площади кухни в общей площади, этаж и площадь кухни.
#
# Отрицательная корреляция с удаленностью от центра, долей жилой площади и количеству комнат.
#
# Зависимость от года, месяца и дня размещения объявления не существенная.

# %% [markdown]
# ### Анализ зависимости цены квадратного метра от различных факторов

# %% [markdown]
# #### Построим сводные таблицы

# %%
def result_table(column):
    '''
    функция возвращает сводную таблицу, группирующую информацию по заданному столбцу 
    и расчитывающую медиану значения цены за квадратный метр
    '''
    result_table = rent_data_filtered.pivot_table(index=column,
                                         values='price_per_meter',
                                         aggfunc='median').style.background_gradient('coolwarm')
    return result_table

# %%
#определим столбцы для группировки
result_columns = ['floor_category', 'day', 'month', 'year', 'distance_from_center', 'is_apartment', 'open_plan', 'studio']

# %%
#получим сводные таблицы
for item in result_columns:
    display(result_table(item))
# Out:
# <style  type="text/css" >
#     #T_64bc78ec_dfe8_11eb_85f1_02420a396374row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_64bc78ec_dfe8_11eb_85f1_02420a396374row1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_64bc78ec_dfe8_11eb_85f1_02420a396374row2_col0 {
#             background-color:  #9fbfff;
#             color:  #000000;
#         }</style><table id="T_64bc78ec_dfe8_11eb_85f1_02420a396374" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >price_per_meter</th>    </tr>    <tr>        <th class="index_name level0" >floor_category</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_64bc78ec_dfe8_11eb_85f1_02420a396374level0_row0" class="row_heading level0 row0" >Другой</th>
# ...

# %% [markdown]
# На сводных таблицах видно, что цена квартир для первого и последнего этажа ниже, чем для любого другого.
#
# Медианное значение цены по разным дням и месяцам размещения практически не меняется. Данные сходятся со значением коэффициентов корреляции.
#
# Цены в 2014 и 2019 году были выше, чем в период с 2015 по 2018. ***Как оказалось, выбросы влияли на цену в 2014 году, без учетов выбросов цены стали ниже***
#
# Также по созданной колонке расстояния от центра видно, что квартиры расположенные ближе к центру стоят значительно дороже

# %% [markdown]
#  #### Построим графики средней цены квадратного метра по разным столбцам

# %%
for columns in result_columns:
    rent_data_filtered.groupby(columns)['price_per_meter'].mean().plot(kind='bar', grid=True)
    plt.title('Зависимость средней цены квадратного метра')
    plt.ylabel('Цена за 1 кв.м., тыс.руб.')
    plt.show();

# %% [markdown]
# #### Выводы из анализа

# %% [markdown]
# По графикам и сводным таблицам видно, что:
# - цена квартиры зависит от этажа (если этаж первый или последний, то цена ниже)
# - день размещения объявления не влияет на цену
# - месяц размещения объявления не влияет на цену
# - год размещения объявленния влияет на цену, но это связано с экономическими факторами в стране и врядли может быть использовано при построении модели расчета цены.
# - расстояние от центра влияет на цену квартиры (чем дальше тем дешевле)
# - апартаменты стоят дороже (хотя заполненных данных мало, чтобы сделать окончательный вывод)
# - квартиры со свободной планировкой стоят дороже.
# - студии стоят дороже.

# %% [markdown]
# ### Определим 10 населенных пунктов с наибольшим количеством объявлений

# %%
grouped_data = rent_data_filtered.pivot_table(index='locality_name', 
                        values='price_per_meter', 
                        aggfunc=['count', 'mean']).reset_index()

# %%
top_10_localities = grouped_data.sort_values(by=('count','price_per_meter'), ascending=False).head(10)

# %%
top_10_localities
# Out:
#          locality_name           count            mean
#                        price_per_meter price_per_meter
# 33     Санкт-Петербург           13828      105.725194
# 199     поселок Мурино             550       85.603645
# 252     поселок Шушары             436       78.578068
# 3           Всеволожск             393       67.169389
# 32              Пушкин             345      101.695331
# 13             Колпино             336       75.370025
# 206  поселок Парголово             326       90.332263
# 6              Гатчина             301       69.293357
# 88     деревня Кудрово             298       92.409726
# 4               Выборг             226       58.350525

# %% [markdown]
# Самые дорогие квартиры в Санкт-Петербурге и Пушкине, самые дешевые в Выборге.

# %% [markdown]
# ### Рассмотрим отдельно информацию о квартирах расположенных в центре Санкт-Петербурга

# %% [markdown]
# #### Определим центр города для фильтрации данных

# %%
spb_data = rent_data_filtered.loc[rent_data.locality_name == 'Санкт-Петербург'].copy()

# %%
spb_data['kms_from_center'] = round(spb_data.cityCenters_nearest / 1000)

# %%
spb_data.groupby('kms_from_center')['price_per_meter'].median().plot(kind='bar')
plt.title('Зависимость средней цены метра жилья от центра Санкт-Петербурга')
plt.xlabel('Количество километров от центра')
plt.ylabel('Средняя цена');

# %% [markdown]
# На графике видно, что очень близко к центру цена за квадратный метр самая высокая. При отдалении от центра цена начинает снижаться. После 8 километров видна ступенька вниз. Ограничим центр радиусов в 8 км.

# %%
center_data = spb_data[spb_data.kms_from_center < 8]

# %% [markdown]
# #### Оценим числовые значения требуемых столбцов

# %%
center_data[['total_area', 'price_per_meter', 'rooms', 'ceiling_height']].describe()
# Out:
#         total_area  price_per_meter        rooms  ceiling_height
# count  2283.000000      2283.000000  2283.000000     1439.000000
# mean     68.965791       116.447820     2.414805        3.014962
# std      22.052522        23.991997     0.969784        0.322454
# min      13.000000        26.250000     0.000000        2.400000
# 25%      51.000000        97.617814     2.000000        2.750000
# 50%      68.100000       114.705882     2.000000        3.000000
# 75%      85.950000       135.488622     3.000000        3.200000
# max     114.200000       167.187500     6.000000        4.000000

# %% [markdown]
# Большая часть квартир в центе имеет высокие потолки более 75% значений выше 3 метров.
#
# Площади квартир в центре также значительно превышают площади квартир в среднем по всей выборке. Медиана площади составляет 63 квадратных метра.
#
# Медиана количества комнат равна 2. Очень мало квартир с 1 комнатой.
#
# Медиана цены 114 тысяч рублей за квадратный метр также выше значений по всей выборке.

# %% [markdown]
# #### Рассмотрим корреляцию таблицу для данных в центре

# %%
plt.figure(figsize=(15,15))
sns.heatmap(center_data.corr(), cmap='Blues', annot=True, fmt=".2")
plt.title('Корреляция между данными');

# %%
pd.DataFrame(center_data.corr()['price_per_meter'].sort_values(ascending=False)).style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_69d81f0c_dfe8_11eb_85f1_02420a396374row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_69d81f0c_dfe8_11eb_85f1_02420a396374row1_col0 {
#             background-color:  #e9d5cb;
#             color:  #000000;
#         }    #T_69d81f0c_dfe8_11eb_85f1_02420a396374row2_col0 {
#             background-color:  #e8d6cc;
#             color:  #000000;
#         }    #T_69d81f0c_dfe8_11eb_85f1_02420a396374row3_col0 {
#             background-color:  #e1dad6;
#             color:  #000000;
#         }    #T_69d81f0c_dfe8_11eb_85f1_02420a396374row4_col0 {
#             background-color:  #e0dbd8;
#             color:  #000000;
#         }    #T_69d81f0c_dfe8_11eb_85f1_02420a396374row5_col0 {
#             background-color:  #d4dbe6;
#             color:  #000000;
#         }    #T_69d81f0c_dfe8_11eb_85f1_02420a396374row6_col0 {
#             background-color:  #b9d0f9;
#             color:  #000000;
# ...

# %% [markdown]
# В корреляционной таблице видно, что для квартир в центре Санкт-Петербурга факторы влияющие на цену отличаются от факторов, которые были выявлены для всей выборки.
#
# На первом месте идут такие факторы как:
# - Балконы
#
# Самый существенный отрицательный фактор:
# - Количество комнат
#
# День, месяц и год размещения объявления влияют на цену квадратного метра очень слабо.

# %% [markdown]
# #### Посмотрим распределение значений факторов для Санкт-Петербурга

# %%
fig, ax = plt.subplots(1, 4,  figsize=(10, 5))
center_data.boxplot('total_area', ax=ax[0])
center_data.boxplot('price_per_meter', ax=ax[1])
center_data.boxplot('rooms', ax=ax[2])
center_data.boxplot('ceiling_height', ax=ax[3])
plt.title('Распределение значений для Санкт-Петербурга', loc='right')
plt.show();

# %% [markdown]
# По графикам видно, что распределения для центра сместились выше по оси. Площадь, цена за метр, количество комнат и высота потолков в среднем для центра города все эти факторы превышают факторы характерные для всей выборки в целом.

# %% [markdown]
# #### Выводы анали центра города

# %% [markdown]
# Анализ центра города показал, что квартиры в центре отличаются от квартир в целом. У них более высокие потолки, больше комнат и больше площадь.
#
# Также было установлено, что для квартир в центре отличаются факторы, которые более всего влияют на цену квадратного метра. Как в большую так и в меньшую сторону. В большую сторону влиет наличе балкона. В меньшую количество комнат.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# В ходе проекта изучены объявления о продаже недвижимости в Санкт-Петербурге и близлежащих населенных пунктах за период с 2014 по 2019 год.
#
# 1. Изученные данные распределены неравномерно. Практически в каждом значащем столбце имеются выбросы. Встречаются квартиры с очень большой площадью, с очень большой ценой, с очень высокими потолками.
#
# 2. В ходе исследования были выявлены недостатки в данных, которые были устранены:
#
# - Были заполнены пропущенные значения
# - Были отфильтрованы выбивающиеся значения
#
# 3. Населенный пункт с самыми дешевыми квартирами Выборг.
#
# 4. Самые дорогие квартиры в Санкт-Петербурге и Пушкине.
#
#
#
# 5. Для построения модели я бы рекомендовал использовать следующие факторы:
#
# - количество этажей (этот фактор влиял на цену квадратного метра как для выборки в целом так и для данных в центре города, вероятно большинство квартир в домах с высокой этажностью более новые и комфортные нежели старые постройки, без учета исторической части города)
# - доля площади кухни (по всей видимости люди предпочитают квартиры с большими кухнями и цены на такие квартиры выше)
# - удаленность от центра (чем дальше от центра тем цена ниже, этот фактор влиял как для центра города так и для всей выборки в целом)
# - первый или последний этаж (квартиры на этажах в середине дома стоят в среднем дороже)
# - студии и квартиры с свободной планировкой стоят дороже.
#
#
#
#
# 6. Не использовать
# - высота потолков (это фактор влиял на цену по всей видимости из-за косвенного признака близость к центру города)
# - доля жилой площади (это фактор с отрицательной корреляцией, но он напрямую связан с долей площади кухни, поэтому для исключения взаимной корреляции это фактор лучше не использовать)
# - апартаменты из-за малого количества данных.
